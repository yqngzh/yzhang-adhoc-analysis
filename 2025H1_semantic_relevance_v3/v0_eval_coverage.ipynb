# %% [markdown]
# This notebook analyzes coverage of the v0 eval split

# %%
import pandas as pd
import numpy as np
import time
import json
from copy import deepcopy
from google.cloud import bigquery

# %%
df = pd.read_excel("./data/gsl_eval_v0.xlsx")

# %%
df.labelbox_majority_label.value_counts()
# Out:
# partial         400
# not_relevant    400
# relevant        400
# Name: labelbox_majority_label, dtype: int64

# %%
client = bigquery.Client(project="etsy-search-ml-dev")

query_str = """with anno_data as (
  select distinct etsyUUID, query, query as queryEn, listingId, 
  from `etsy-sr-etl-prod.yzhang.sem_rel_human_annotation_v2`
  union all
  select distinct etsyUUID, query, queryEn, listingId, 
  from `etsy-search-ml-dev.aclapp.isearch_semrel_surveyv1_teacherv2_features_w_primaryLang`
),
qlm AS (
  select query_raw query, bin as queryBin 
  from `etsy-batchjobs-prod.snapshots.query_level_metrics_raw`
  where _date = date('2025-02-07')
),
qis AS (
  SELECT query_raw query,
  CASE 
    WHEN class_id = 0 THEN 'broad' 
    WHEN class_id = 1 THEN 'direct_unspecified'
    WHEN class_id = 2 THEN 'direct_specified' 
  END AS qisClass
  FROM `etsy-search-ml-prod.mission_understanding.qis_scores`
),
qisv2 AS (
  SELECT query,
  CASE 
    WHEN prediction = 0 THEN 'broad' 
    WHEN prediction = 1 THEN 'direct_unspecified'
    WHEN prediction = 2 THEN 'direct_specified' 
  END AS qisClassV2
  FROM `etsy-search-ml-prod.mission_understanding.qis_scores_v2`
),
lfb AS (
  SELECT key listingId, 
    verticaListings_taxonomyPath listingTaxo,
  FROM `etsy-ml-systems-prod.feature_bank_v2.listing_feature_bank_most_recent`
)
select 
  etsyUUID, query, queryEn, listingId, queryBin, qisClass, qisClassV2, listingTaxo
from anno_data
left join qlm using (query)
left join qis using (query)
left join qisv2 using (query)
left join lfb using (listingId)
"""

query_job = client.query(query_str)
features_df = query_job.result().to_dataframe()
# Out:
# /Users/yzhang/development/yzhang-adhoc-analysis/venv/lib/python3.10/site-packages/google/auth/_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
merged_df = pd.merge(df, features_df, on=["etsyUUID", "query", "listingId"], how="left")

# %%
merged_df["listingTopTaxo"] = merged_df.listingTaxo.apply(lambda x: x.split(".")[0])

# %%
merged_df[["etsyUUID", "query", "listingId", "anno_data_source", "queryBin", "qisClass", "qisClassV2", "listingTopTaxo"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1200 entries, 0 to 1199
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   etsyUUID          1200 non-null   object
#  1   query             1200 non-null   object
#  2   listingId         1200 non-null   int64
#  3   anno_data_source  1200 non-null   object
#  4   queryBin          1170 non-null   object
#  5   qisClass          1189 non-null   object
#  6   qisClassV2        1188 non-null   object
#  7   listingTopTaxo    1200 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 84.4+ KB

# %%
merged_df.anno_data_source.str.startswith("us").value_counts()
# Out:
# True     656
# False    544
# Name: anno_data_source, dtype: int64

# %%
len(merged_df["query"].unique())
# Out:
# 859

# %%
query_df = merged_df[["query", "queryBin", "qisClassV2"]].drop_duplicates()
query_df.shape
# Out:
# (859, 3)

# %%
query_df.queryBin.value_counts()
# Out:
# head      236
# top.01    219
# top.1     158
# tail      114
# torso     108
# Name: queryBin, dtype: int64

# %%
query_df.qisClassV2.value_counts()
# Out:
# direct_specified      365
# broad                 271
# direct_unspecified    216
# Name: qisClassV2, dtype: int64

# %%
listing_df = merged_df[["listingId", "listingTopTaxo"]].drop_duplicates()

# %%
len(listing_df.listingId.unique())
# Out:
# 1200

# %%
listing_df.listingTopTaxo.value_counts()
# Out:
# home_and_living                246
# clothing                       158
# jewelry                        141
# art_and_collectibles           137
# paper_and_party_supplies       115
# craft_supplies_and_tools       107
# accessories                     59
# toys_and_games                  51
# weddings                        45
# bags_and_purses                 40
# electronics_and_accessories     39
# bath_and_beauty                 28
# books_movies_and_music          20
# pet_supplies                     8
# shoes                            6
# Name: listingTopTaxo, dtype: int64

# %% [markdown]
# gift queries

# %%
import re

# %%
def checkIsGiftQuery(query_str):
    pattern = r"(?i)\bgift|\bfor (\bhim|\bher|\bmom|\bdad|\bmother|\bfather|\bdaughter|\bson|\bwife|\bhusband|\bpartner|\baunt|\buncle|\bniece|\bnephew|\bfiance|\bcousin|\bin law|\bboyfriend|\bgirlfriend|\bgrand|\bfriend|\bbest friend)"
    result = re.search(pattern, query_str) 
    is_gift = result is not None
    return is_gift

# %%
def checkIsGiftInDF(row):
    if row["anno_data_source"].startswith("us"):
        return checkIsGiftQuery(row["query"])
    else:
        return checkIsGiftQuery(row["queryEn_x"])

# %%
merged_df["queryIsGift"] = merged_df.apply(checkIsGiftInDF, axis=1)

# %%
merged_df[merged_df["anno_data_source"] == "us_v2-gift"].queryIsGift.value_counts()
# Out:
# True    60
# Name: queryIsGift, dtype: int64

# %%
merged_df[merged_df["anno_data_source"] != "us_v2-gift"].queryIsGift.value_counts()
# Out:
# False    1093
# True       47
# Name: queryIsGift, dtype: int64

# %%
merged_df[np.logical_and(merged_df.queryIsGift, merged_df["anno_data_source"] != "us_v2-gift")]
# Out:
#                                                   query  \
# 54                          anniversary gifts for women
# 77                                 unique gifts for her
# 82                            personalized gift for him
# 115                                        gift for dog
# 146                      30th wedding anniversary gifts
# 170                                unique gifts for her
# 209                                        wedding gift
# 210                           teacher appreciation gift
# 216                                           home gift
# 231                                      trauergeschenk
# 283                                     gifts for women
# 305                                      gifts for kids
# 400                                     jungle gift box
# 402                           personalized gift for mum
# 440                               gift basket for women
# 443                                         couple gift
# 449                                     gifts for women
# 464                          abschiedsgeschenk kollegen
# 468                           teacher appreciation gift
# 474                                      thank you gift
# 494   Luxury Wedding Hamper/Personalised Wedding Fra...
# 506                                back to college gift
# 509                    Personalized gift card envelopes
# 526                                     gifts for women
# 565                                unique gifts for her
# 590                          abschiedsgeschenk kollegen
# 650                               wedding gift bar sign
# 661                                unique gifts for her
# 692                           anniversary gifts for him
# 702                             geschenk opa geburtstag
# 728                                unique gifts for her
# 729                                     gifts for women
# 738                        personalized gifts for women
# 804                                     gifts for women
# 825                                     engagement gift
# 827                            geldgeschenk einschulung
# 830                                     jungle gift box
# 855                                unique gifts for her
# 894                                  best holiday gifts
# 904                              pensierini per neonati
# 928                                       bassoon gifts
# 971                                                gift
# 1011                        grandson birthday gift 24th
# 1022                                      handmade gift
# 1039                                     gifts for kids
# 1105                                    gifts for women
# 1177                             1st birthday gift toys
#
#                         queryEn_x   listingId  etsy_url  atlas_url  \
# 54                            NaN   801724215       NaN        NaN
# 77           unique gifts for her  1405418532       NaN        NaN
# 82                            NaN  1393233546       NaN        NaN
# 115                           NaN  1321188874       NaN        NaN
# 146                           NaN  1529669642       NaN        NaN
# 170                           NaN  1670022097       NaN        NaN
# 209                           NaN  1490399459       NaN        NaN
# 210     teacher appreciation gift  1377489767       NaN        NaN
# 216                           NaN  1326183511       NaN        NaN
# 231                 sympathy gift  1737503881       NaN        NaN
# 283               gifts for women  1112997443       NaN        NaN
# 305                           NaN  1297761172       NaN        NaN
# 400               jungle gift box  1343812045       NaN        NaN
# 402                           NaN  1675261111       NaN        NaN
# 440                           NaN   942708705       NaN        NaN
# 443                           NaN  1403034980       NaN        NaN
# 449               gifts for women   807059249       NaN        NaN
# 464      farewell gift colleagues  1635369681       NaN        NaN
# 468     teacher appreciation gift  1640090703       NaN        NaN
# 474                           NaN  1183730103       NaN        NaN
# 494                           NaN  1659026554       NaN        NaN
# 506          back to college gift   203749206       NaN        NaN
# 509                           NaN   637209202       NaN        NaN
# 526                           NaN   177585338       NaN        NaN
# 565          unique gifts for her  1470951207       NaN        NaN
# 590      farewell gift colleagues  1499956409       NaN        NaN
# 650                           NaN  1536960888       NaN        NaN
# 661                           NaN  1503354032       NaN        NaN
# 692                           NaN  1383400050       NaN        NaN
# 702         gift grandpa birthday  1559861137       NaN        NaN
# 728                           NaN   624493147       NaN        NaN
# 729               gifts for women  1468526006       NaN        NaN
# 738                           NaN  1416623939       NaN        NaN
# 804               gifts for women  1322651680       NaN        NaN
# 825                           NaN  1241667747       NaN        NaN
# 827   cash gift school enrollment  1743193805       NaN        NaN
# 830               jungle gift box  1633469933       NaN        NaN
# 855                           NaN   895632867       NaN        NaN
# 894                           NaN   582065969       NaN        NaN
# 904     little gifts for newborns  1558311514       NaN        NaN
# 928                           NaN   777241227       NaN        NaN
# 971                           NaN   739312118       NaN        NaN
# 1011                          NaN  1574447284       NaN        NaN
# 1022                handmade gift   993944520       NaN        NaN
# 1039                          NaN  1183916600       NaN        NaN
# 1105              gifts for women   792145505       NaN        NaN
# 1177                          NaN  1447439433       NaN        NaN
#
#                                         titleEn_vertica  \
# 54    Tiger eye brass Ring, Handmade Ring, Women Rin...
# 77    Vintage zodiac charm pendant - sagittarius cha...
# 82    Adventure Book Scrapbook Couples Gift for Boyf...
# 115   Farmhouse Christmas Ornament Jack Russell Terr...
# 146   Personalised 30th Anniversary Gift, Pearl Anni...
# 170   Small brass contemporary ring, Statement Uniqu...
# 209   Personalized Cutting Board With Handle, Custom...
# 210   A Parents Thank You Printable Nursery Teachers...
# 216   Round Personalized Charcuterie Board Set/19pcs...
# 231   Mourning light memorial light lantern farewell...
# 283   Birthstone Necklace, Personalized Necklace, Bi...
# 305   Personalised Bunny Rabbit, New Baby Gift, Pers...
# 400   Watercolour jungle pink animals Personalised C...
# 402   Personalised Birth Flower Jug|Ceramic Floral V...
# 440   Personalized Galentine&#39;s Day Gift For Her,...
# 443   Personalised Engagement Bottle Box Personalise...
# 449   Green moss agate bracelet, women&#39;s bracele...
# 464   Storage jar with engraving &quot;Nervennahrung...
# 468   Never Underestimate The Difference You Made Ap...
# 474   Editable Eucalyptus Greenery Baby Shower favor...
# 494   Personalised Couples Passport Cover & Suitcase...
# 506   Notebook Paper bow tie. College Ruled bow tie....
# 509   Christmas Gift Card Holders, Christmas Gift Ca...
# 526   Hummingbird Necklace - Bird Necklace - Bird Je...
# 565   Personalized jute bag MOM-GRANDMA | Market bag...
# 590   Farewell gift colleague cup, gift colleague fa...
# 650   Espresso Martini Bar Sign, Espresso Martini Co...
# 661                   FATIMA MIDAXI MULTICOLOURED dress
# 692   Cute Space Cat Anniversary Card | My World, My...
# 702   Grandpa Fathers Day, Grandpa Birthday Gift, Pe...
# 728   Personalized Wedding Gift /  Jewelry Dish / Da...
# 729   Handmade Paper Foldable Lamp, Unique Bedside N...
# 738   Personalised Minimalist Name Necklace with Box...
# 804   Customizable scratch-off messages kit - 50 thi...
# 825   Bride Shirt, Bride to Be, Engagement Shirt, Ho...
# 827   SVG file including commercial license 30 gift ...
# 830   Safari Truck Big Decor Cutout, Jungle Animal B...
# 855   Handmade yin yang clay earrings, retro jewelry...
# 894   Heeey Yoooo Daaaad! Card | Goonies Inspired Fa...
# 904   Baby girl bib with name, personalized bib, ter...
# 928                                Bass Clef Sweatshirt
# 971   Minimalist Holiday Gift Wrap 4, Ornament Wrapp...
# 1011  Personalised Nephew 24th Birthday Card Nephew ...
# 1022  Father&#39;s Day Gift, Personalised Men&#39;s ...
# 1039  Ruby Heart Earrings by Caitlyn Minimalist • Ev...
# 1105  DO YOUR WHISKY | Whiskey Infusion Set | 10 Spi...
# 1177  Personalized Wooden Sorting Barn - Sorting Toy...
#
#                           etsyUUID platform userLanguage  \
# 54    EueMU1ppuQpAY2hp5qEPMdMhkFbd      boe        en-US
# 77    EuoVxlZmrGD-8ul8vpKBu_A1Pw9d      boe           fr
# 82    Eu5sFjO5nQZ_vwAr8iAzYrL7nDc1      boe        en-US
# 115   EuaTiDIgon6rz3CCDTVHm95mc915      boe        en-US
# 146   EuKFdRLCuzFmYRG3Iuw3CBcfQU12      web        en-GB
# 170   Euao8J8mQlKUea0NbP3Q4a__bu61      boe        en-US
# 209   EuJ2-g2LX1-WpK4hwWbiNwka2Mde      web        en-US
# 210   EuuIAuFuQTGYA3VrjJEJlAZC_Q91      boe           nl
# 216   EuqLmuRY0wVH_cs4vC4rJXVEcW4c      boe        en-US
# 231   EuaEY2rK-72xUPB70W2j0VzCiIc8      web           de
# 283   Eu_btmtZ_H__zzgEo04aBkt1m1c3      boe           fr
# 305   EuMbAYrPQboD98ICpYwokwu8BM75      boe        en-US
# 400   EuxzMa7wam04ZRoO6i5BHfgFZac2      web           nl
# 402   EuWlBLu6_c1UkQPVJ7A4TpzoY207      boe        en-GB
# 440   EuBQeCjPX44p9Dw1H4tmW8NNbJ01      web        en-US
# 443   EuRzLzYJYIxaqzOUhjCpaY34r2da      boe        en-GB
# 449   Eu_btmtZ_H__zzgEo04aBkt1m1c3      boe           fr
# 464   EuhzMx0ffOH7B3fkB1RSM1JngM2e      boe           de
# 468   EuuIAuFuQTGYA3VrjJEJlAZC_Q91      boe           nl
# 474   Euij388thwBdfDc0aizlHPe6t399      web        en-US
# 494   EulNk4E7roqBnFyTPzaFEzevxxdc      web        en-GB
# 506   EuSQe95s6IWDgXgZqIxUNdTJQ-bc      boe           nl
# 509   Eufh7PptMMg_yKafV95mWoK6CXad      boe        en-US
# 526   EubeL6FJU5HydItGMGpt3lhtYle5      boe        en-GB
# 565   Eu0dyTXhwPmHk4lRivKvpavhmi22      boe           fr
# 590   EuhzMx0ffOH7B3fkB1RSM1JngM2e      boe           de
# 650   EuPwiMmiCUXwytCOZwIIBIN5IBcb      web        en-US
# 661   EuCddC6C2q-UN6FEEwNbIe5S-68d      boe        en-US
# 692   EuAbi1jDlW9GHLOwqTcJhPWlLMb2      boe        en-US
# 702   EuT-XiPv--EkxAXCiuN0tPFDCee5      boe           de
# 728   EuQI0syVPoBznGpzCXAonoro3b6e      boe        en-US
# 729   Eu1E1sMPQzpMzJEW-dXGX6ZuIzf1      boe           fr
# 738   Eu3B7xJlbuNGEuqDVWijoW85LV6d      boe        en-US
# 804   Eu_btmtZ_H__zzgEo04aBkt1m1c3      boe           fr
# 825   Eusd0mbJO_mYieFPDpYCNoJ3JV3f      web        en-US
# 827   EuZyD7N1EcmIVe0n9JyS3E0Aij74      boe           de
# 830   EuxzMa7wam04ZRoO6i5BHfgFZac2      web           nl
# 855   EuRtuPO0Y54UgVDOH-9tCeFAA5d8      boe        en-US
# 894   Eugn72m8-Vwgvtb3yLrYqUgclF41      boe        en-US
# 904   Eu43vZPW3XK0EPivL84wepLH-87c      web           it
# 928   EusbDDhsP2vCz6tdecAYJ91MPF72      web        en-US
# 971   EuBShYJ-wgaNOHNlY6C-DWlOjq33      boe        en-US
# 1011  EuAgJzcqg_vmnJPNL8MsYdw4zI78      web        en-GB
# 1022  Eu8o_WBPX6EZuaUhj0hoB0Iqvpa4      boe           es
# 1039  Eu6VYFDA0JgVndp05pVKOa8eYq9f      boe        en-US
# 1105  Eu1E1sMPQzpMzJEW-dXGX6ZuIzf1      boe           fr
# 1177  Euk6EdXE_2bdbbUrc1ktpX-CCb93      boe        en-US
#
#               anno_data_source  ...  label_annotator_2 label_annotator_3  \
# 54                 us_v2-broad  ...           relevant          relevant
# 77                     intl-fr  ...           relevant          relevant
# 82                 us_v2-broad  ...           relevant          relevant
# 115                us_v2-broad  ...           relevant          relevant
# 146                us_v2-broad  ...           relevant          relevant
# 170                us_v2-broad  ...           relevant          relevant
# 209                us_v2-broad  ...           relevant          relevant
# 210                    intl-nl  ...           relevant          relevant
# 216                us_v2-broad  ...            partial           partial
# 231                    intl-de  ...           relevant          relevant
# 283                    intl-fr  ...           relevant          relevant
# 305                us_v2-broad  ...           relevant          relevant
# 400                    intl-nl  ...           relevant          relevant
# 402                us_v2-broad  ...           relevant          relevant
# 440   us_v2-direct_unspecified  ...            partial           partial
# 443                us_v2-broad  ...           relevant          relevant
# 449                    intl-fr  ...           relevant          relevant
# 464                    intl-de  ...            partial           partial
# 468                    intl-nl  ...           relevant          relevant
# 474                us_v2-broad  ...           relevant          relevant
# 494     us_v2-direct_specified  ...       not_relevant      not_relevant
# 506                    intl-nl  ...           relevant          relevant
# 509   us_v2-direct_unspecified  ...            partial           partial
# 526                us_v2-broad  ...           relevant          relevant
# 565                    intl-fr  ...           relevant          relevant
# 590                    intl-de  ...           relevant          relevant
# 650   us_v2-direct_unspecified  ...           relevant          relevant
# 661                us_v2-broad  ...           relevant          relevant
# 692                us_v2-broad  ...            partial           partial
# 702                    intl-de  ...           relevant          relevant
# 728                us_v2-broad  ...           relevant          relevant
# 729                    intl-fr  ...            partial           partial
# 738                us_v2-broad  ...           relevant          relevant
# 804                    intl-fr  ...       not_relevant           partial
# 825                us_v2-broad  ...           relevant          relevant
# 827                    intl-de  ...       not_relevant      not_relevant
# 830                    intl-nl  ...           relevant      not_relevant
# 855                us_v2-broad  ...           relevant          relevant
# 894                us_v2-broad  ...       not_relevant      not_relevant
# 904                    intl-it  ...            partial          relevant
# 928                us_v2-broad  ...       not_relevant      not_relevant
# 971                us_v2-broad  ...            partial           partial
# 1011               us_v2-broad  ...            partial           partial
# 1022                   intl-es  ...           relevant           partial
# 1039               us_v2-broad  ...       not_relevant      not_relevant
# 1105                   intl-fr  ...            partial           partial
# 1177  us_v2-direct_unspecified  ...            partial           partial
#
#      is_gsl_v0_eval                                          queryEn_y  \
# 54             True                        anniversary gifts for women
# 77             True                               unique gifts for her
# 82             True                          personalized gift for him
# 115            True                                       gift for dog
# 146            True                     30th wedding anniversary gifts
# 170            True                               unique gifts for her
# 209            True                                       wedding gift
# 210            True                          teacher appreciation gift
# 216            True                                          home gift
# 231            True                                      sympathy gift
# 283            True                                    gifts for women
# 305            True                                     gifts for kids
# 400            True                                    jungle gift box
# 402            True                          personalized gift for mum
# 440            True                              gift basket for women
# 443            True                                        couple gift
# 449            True                                    gifts for women
# 464            True                           farewell gift colleagues
# 468            True                          teacher appreciation gift
# 474            True                                     thank you gift
# 494            True  Luxury Wedding Hamper/Personalised Wedding Fra...
# 506            True                               back to college gift
# 509            True                   Personalized gift card envelopes
# 526            True                                    gifts for women
# 565            True                               unique gifts for her
# 590            True                           farewell gift colleagues
# 650            True                              wedding gift bar sign
# 661            True                               unique gifts for her
# 692            True                          anniversary gifts for him
# 702            True                              gift grandpa birthday
# 728            True                               unique gifts for her
# 729            True                                    gifts for women
# 738            True                       personalized gifts for women
# 804            True                                    gifts for women
# 825            True                                    engagement gift
# 827            True                        cash gift school enrollment
# 830            True                                    jungle gift box
# 855            True                               unique gifts for her
# 894            True                                 best holiday gifts
# 904            True                          little gifts for newborns
# 928            True                                      bassoon gifts
# 971            True                                               gift
# 1011           True                        grandson birthday gift 24th
# 1022           True                                      handmade gift
# 1039           True                                     gifts for kids
# 1105           True                                    gifts for women
# 1177           True                             1st birthday gift toys
#
#      queryBin            qisClass          qisClassV2  \
# 54     top.01               broad               broad
# 77     top.01               broad               broad
# 82     top.01               broad               broad
# 115    top.01               broad               broad
# 146     top.1               broad               broad
# 170    top.01               broad               broad
# 209    top.01               broad               broad
# 210    top.01               broad               broad
# 216    top.01               broad               broad
# 231    top.01               broad               broad
# 283    top.01               broad               broad
# 305    top.01               broad               broad
# 400      head               broad    direct_specified
# 402    top.01               broad               broad
# 440    top.01  direct_unspecified  direct_unspecified
# 443    top.01               broad               broad
# 449    top.01               broad               broad
# 464    top.01               broad               broad
# 468    top.01               broad               broad
# 474    top.01               broad               broad
# 494      head    direct_specified    direct_specified
# 506    top.01               broad               broad
# 509      head  direct_unspecified    direct_specified
# 526    top.01               broad               broad
# 565    top.01               broad               broad
# 590    top.01               broad               broad
# 650     torso  direct_unspecified  direct_unspecified
# 661    top.01               broad               broad
# 692    top.01               broad               broad
# 702     top.1               broad               broad
# 728    top.01               broad               broad
# 729    top.01               broad               broad
# 738    top.01               broad               broad
# 804    top.01               broad               broad
# 825    top.01               broad               broad
# 827     top.1               broad               broad
# 830      head               broad    direct_specified
# 855    top.01               broad               broad
# 894     top.1               broad               broad
# 904      tail               broad               broad
# 928      head               broad               broad
# 971    top.01               broad               broad
# 1011     tail               broad               broad
# 1022   top.01               broad               broad
# 1039   top.01               broad               broad
# 1105   top.01               broad               broad
# 1177     head  direct_unspecified  direct_unspecified
#
#                                             listingTaxo  \
# 54                        jewelry.rings.statement_rings
# 77                  jewelry.necklaces.pendant_necklaces
# 82    books_movies_and_music.books.blank_books.journ...
# 115   home_and_living.home_decor.seasonal_decor.chri...
# 146   home_and_living.home_decor.picture_frames_and_...
# 170                       jewelry.rings.statement_rings
# 209   home_and_living.kitchen_and_dining.dining_and_...
# 210          art_and_collectibles.prints.digital_prints
# 216             home_and_living.home_decor.home_accents
# 231   home_and_living.home_decor.candles_and_home_fr...
# 283       jewelry.necklaces.monogram_and_name_necklaces
# 305   toys_and_games.toys.stuffed_animals_and_plushi...
# 400   paper_and_party_supplies.party_supplies.party_...
# 402       home_and_living.home_decor.home_accents.vases
# 440   bath_and_beauty.spa_and_relaxation.spa_kits_an...
# 443    weddings.gifts_and_mementos.gifts_for_the_couple
# 449                  jewelry.bracelets.beaded_bracelets
# 464   home_and_living.kitchen_and_dining.kitchen_sto...
# 468          art_and_collectibles.prints.digital_prints
# 474   paper_and_party_supplies.paper.invitations_and...
# 494    weddings.gifts_and_mementos.gifts_for_the_couple
# 506       accessories.suit_and_tie_accessories.bow_ties
# 509        paper_and_party_supplies.paper.gift_wrapping
# 526                 jewelry.necklaces.pendant_necklaces
# 565                               bags_and_purses.totes
# 590   home_and_living.kitchen_and_dining.drink_and_b...
# 650   paper_and_party_supplies.party_supplies.party_...
# 661                    clothing.womens_clothing.dresses
# 692   paper_and_party_supplies.paper.greeting_cards....
# 702          art_and_collectibles.prints.digital_prints
# 728                 jewelry.jewelry_storage.ring_dishes
# 729   home_and_living.lighting.light_fixtures.wall_l...
# 738       jewelry.necklaces.monogram_and_name_necklaces
# 804   paper_and_party_supplies.paper.greeting_cards....
# 825   clothing.gender_neutral_adult_clothing.tops_an...
# 827   craft_supplies_and_tools.patterns_and_how_to.c...
# 830   paper_and_party_supplies.party_supplies.party_...
# 855                    jewelry.earrings.dangle_earrings
# 894   paper_and_party_supplies.paper.greeting_cards....
# 904   bath_and_beauty.baby_and_child_care.bibs_and_b...
# 928   clothing.gender_neutral_adult_clothing.hoodies...
# 971   paper_and_party_supplies.paper.gift_wrapping.w...
# 1011      paper_and_party_supplies.paper.greeting_cards
# 1022    bags_and_purses.wallets_and_money_clips.wallets
# 1039                     jewelry.earrings.stud_earrings
# 1105  home_and_living.food_and_drink.herbs_and_spice...
# 1177                   toys_and_games.toys.pretend_play
#
#                 listingTopTaxo queryIsGift
# 54                     jewelry        True
# 77                     jewelry        True
# 82      books_movies_and_music        True
# 115            home_and_living        True
# 146            home_and_living        True
# 170                    jewelry        True
# 209            home_and_living        True
# 210       art_and_collectibles        True
# 216            home_and_living        True
# 231            home_and_living        True
# 283                    jewelry        True
# 305             toys_and_games        True
# 400   paper_and_party_supplies        True
# 402            home_and_living        True
# 440            bath_and_beauty        True
# 443                   weddings        True
# 449                    jewelry        True
# 464            home_and_living        True
# 468       art_and_collectibles        True
# 474   paper_and_party_supplies        True
# 494                   weddings        True
# 506                accessories        True
# 509   paper_and_party_supplies        True
# 526                    jewelry        True
# 565            bags_and_purses        True
# 590            home_and_living        True
# 650   paper_and_party_supplies        True
# 661                   clothing        True
# 692   paper_and_party_supplies        True
# 702       art_and_collectibles        True
# 728                    jewelry        True
# 729            home_and_living        True
# 738                    jewelry        True
# 804   paper_and_party_supplies        True
# 825                   clothing        True
# 827   craft_supplies_and_tools        True
# 830   paper_and_party_supplies        True
# 855                    jewelry        True
# 894   paper_and_party_supplies        True
# 904            bath_and_beauty        True
# 928                   clothing        True
# 971   paper_and_party_supplies        True
# 1011  paper_and_party_supplies        True
# 1022           bags_and_purses        True
# 1039                   jewelry        True
# 1105           home_and_living        True
# 1177            toys_and_games        True
#
# [47 rows x 23 columns]

# %%
query_gift_df = merged_df[["query", "queryIsGift"]].drop_duplicates()
query_gift_df.shape
# Out:
# (859, 2)

# %%
query_gift_df.queryIsGift.value_counts()
# Out:
# False    781
# True      78
# Name: queryIsGift, dtype: int64
